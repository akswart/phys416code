# %%
from Prob15_schro import *

# %% [markdown]
# Now we run for E < U
#
# Note that E = .125 for all runs
#
# Also, we have expanded L from L=100 to L = 600

# %%
schro(.25)
# Out:
# Particle Energy is: 0.125
# Max_iter: 16001

# %% [markdown]
# For E = U

# %%
schro(.125)
# Out:
# Particle Energy is: 0.125
# Max_iter: 16001

# %% [markdown]
# Finally for E > U

# %%
schro(.75)
# Out:
# Particle Energy is: 0.125
# Max_iter: 16001
